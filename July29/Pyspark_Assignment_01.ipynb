# %%
df.to_csv('students_summary.csv', index=False)
from google.colab import files
files.download('students_summary.csv')

# %%
#Bonus Tasks
totals=df[['Math','Science','English']].sum()
print("Total scores by subject",totals)
print("Subjects with total score",totals.idxmax())
# Out:
# Total scores by subject Math       378
# Science    399
# English    378
# dtype: int64
# Subjects with total score Science

# %%
#5.Line Chart
df.set_index('Name')[['Math', 'Science', 'English']].plot(marker='o')
plt.title("Subject-wise Scores")
plt.ylabel("Marks")
plt.grid(True)
plt.show()

# %%
#5.Chart Exercise
import matplotlib.pyplot as plt
plt.figure(figsize=(8,5))
plt.bar(df['Name'],df['Average'],color='Pink')
plt.xlabel('Name')
plt.ylabel('Average Score')
plt.title('Average Scores of Students')
plt.grid(True)
plt.xticks(rotation=45)
plt.show()

# %%
#4.Sorting
sorted_df=df.sort_values(by='English',ascending=False)
print("Top 3 students by English score:")
print(sorted_df.head(3))
# Out:
# Top 3 students by English score:
#     Name  Math  Science  English    Average
# 1  Priya    92       89       96  92.333333
# 3  Anita    88       95       90  91.000000
# 0   Amit    78       85       74  79.000000

# %%
#3.Filtering students
print("Students with Science > 80:")
print(df[df['Science']>80])
#Students with avaerage score less than 70
print("Students with average < 70:")
print(df[df['Average']<70])
# Out:
# Students with Science > 80:
#     Name  Math  Science  English    Average
# 0   Amit    78       85       74  79.000000
# 1  Priya    92       89       96  92.333333
# 3  Anita    88       95       90  91.000000
# Students with average < 70:
#     Name  Math  Science  English    Average
# 2  Kiran    65       70       60  65.000000
# 4   Ravi    55       60       58  57.666667

# %%
#2.Calculating Average Scores
df['Average']=df[['Math','Science','English']].mean(axis=1)
print(df)
# Out:
#     Name  Math  Science  English    Average
# 0   Amit    78       85       74  79.000000
# 1  Priya    92       89       96  92.333333
# 2  Kiran    65       70       60  65.000000
# 3  Anita    88       95       90  91.000000
# 4   Ravi    55       60       58  57.666667

# %%
import pandas as pd
df=pd.read_csv('students.csv')
print("First 3 rows:")
print(df.head(3))
# Out:
# First 3 rows:
#     Name  Math  Science  English
# 0   Amit    78       85       74
# 1  Priya    92       89       96
# 2  Kiran    65       70       60

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-f2b688b2-229a-42df-9a9c-84284da7ec0c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f2b688b2-229a-42df-9a9c-84284da7ec0c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
